# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)}) # set font and plot size to be larger
import seaborn as sns

# %%
questions = pd.read_csv('questions.csv')
codes = pd.read_csv('codes.csv')
answers = pd.read_csv('answers.csv')

# %%
answers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2026 entries, 0 to 2025
# Data columns (total 98 columns):
# Unnamed: 0     2026 non-null object
# Unnamed: 1     2026 non-null object
# Unnamed: 2     2026 non-null object
# Unnamed: 3     2026 non-null object
# Unnamed: 4     2026 non-null object
# Unnamed: 5     2026 non-null object
# Unnamed: 6     2026 non-null object
# Unnamed: 7     2026 non-null object
# Unnamed: 8     2026 non-null object
# Unnamed: 9     2026 non-null object
# Unnamed: 10    2026 non-null object
# Unnamed: 11    2026 non-null object
# Unnamed: 12    2026 non-null object
# Unnamed: 13    2026 non-null object
# Unnamed: 14    9 non-null object
# Unnamed: 15    2026 non-null object
# Unnamed: 16    1721 non-null object
# Unnamed: 17    1721 non-null object
# Unnamed: 18    1721 non-null object
# Unnamed: 19    1721 non-null object
# Unnamed: 20    1721 non-null object
# Unnamed: 21    1721 non-null object
# Unnamed: 22    1494 non-null object
# ...

# %%
answers.shape
# Out:
# (2026, 98)

# %%
temp = answers
temp.drop_duplicates(inplace=True, keep=False)

# %%
temp.shape
# Out:
# (2026, 98)

# %%
answers.describe()
# Out:
#        Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# count        2026       2026       2026       2026       2026       2026
# unique       2025          3          4          4          7          5
# top            ID      Geral   Feminino        CDE         SE    30 a 49
# freq            2       2024       1056       1584       1005        950
#
#        Unnamed: 6 Unnamed: 7          Unnamed: 8       Unnamed: 9  ...  \
# count        2026       2026                2026             2026  ...
# unique          6          4                   9                8  ...
# top       Android   Feminino  De R$999 a R$1.996  De 30 a 39 anos  ...
# freq         1871       1056                 507              587  ...
#
#        Unnamed: 88 Unnamed: 89 Unnamed: 90 Unnamed: 91 Unnamed: 92  \
# count           81          35          19           8           5
# unique           9           8           7           5           4
# ...

# %%
answers['Unnamed: 5'].value_counts()
# Out:
# 30 a 49        950
# 16 a 29        764
# 50+            310
# Leituras_5       1
# Bandeiras_5      1
# Name: Unnamed: 5, dtype: int64

# %%
answers_col = answers[['Unnamed: 5']]
type(answers_col)
# Out:
# pandas.core.frame.DataFrame

# %%
conditional = (answers['Unnamed: 8'] == 'De R$2.995 a R$4.990')
conditional
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 2021     True
# 2022    False
# 2023    False
# 2024    False
# 2025    False
# Name: Unnamed: 8, Length: 2026, dtype: bool

# %%
answers[answers['Unnamed: 8'] == 'De R$2.995 a R$4.990']
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 3             2      Geral   Feminino        CDE         NE    16 a 29
# 15           14      Geral   Feminino        CDE         SE    30 a 49
# 16           15      Geral   Feminino        CDE         CO        50+
# 24           23      Geral  Masculino        CDE         SE    30 a 49
# 25           24      Geral  Masculino        CDE         SE    16 a 29
# ...         ...        ...        ...        ...        ...        ...
# 1978       1977      Geral  Masculino        CDE          S        50+
# 1984       1983      Geral  Masculino        CDE         SE        50+
# 1994       1993      Geral  Masculino        CDE         SE    16 a 29
# 2008       2007      Geral   Feminino        CDE          S        50+
# 2021       2020      Geral   Feminino        CDE         SE    30 a 49
#
#      Unnamed: 6 Unnamed: 7            Unnamed: 8       Unnamed: 9  ...  \
# ...

# %%
answers1=answers.groupby(['Unnamed: 5', 'Unnamed: 8']).size()
answers1=answers1.unstack()
answers1.plot(kind='bar')

# %%
answers.columns = answers.iloc[1]
answers
# Out:
# 1       ID   Leituras_1   Leituras_2   Leituras_3   Leituras_4   Leituras_5  \
# 0       ID  Bandeiras_1  Bandeiras_2  Bandeiras_3  Bandeiras_4  Bandeiras_5
# 1       ID   Leituras_1   Leituras_2   Leituras_3   Leituras_4   Leituras_5
# 2        1        Geral    Masculino          CDE           SE      30 a 49
# 3        2        Geral     Feminino          CDE           NE      16 a 29
# 4        3        Geral     Feminino           AB            S      30 a 49
# ...    ...          ...          ...          ...          ...          ...
# 2021  2020        Geral     Feminino          CDE           SE      30 a 49
# 2022  2021        Geral     Feminino          CDE            S      30 a 49
# 2023  2022        Geral     Feminino          CDE            S      16 a 29
# 2024  2023        Geral     Feminino          CDE            N      16 a 29
# 2025  2024        Geral     Feminino          CDE            N      30 a 49
#
# 1      Leituras_6       Sexo  \
# ...

# %%
answers = answers.set_index('ID')

# %%
answers
# Out:
# 1      Leituras_1   Leituras_2   Leituras_3   Leituras_4   Leituras_5  \
# ID
# ID    Bandeiras_1  Bandeiras_2  Bandeiras_3  Bandeiras_4  Bandeiras_5
# ID     Leituras_1   Leituras_2   Leituras_3   Leituras_4   Leituras_5
# 1           Geral    Masculino          CDE           SE      30 a 49
# 2           Geral     Feminino          CDE           NE      16 a 29
# 3           Geral     Feminino           AB            S      30 a 49
# ...           ...          ...          ...          ...          ...
# 2020        Geral     Feminino          CDE           SE      30 a 49
# 2021        Geral     Feminino          CDE            S      30 a 49
# 2022        Geral     Feminino          CDE            S      16 a 29
# 2023        Geral     Feminino          CDE            N      16 a 29
# 2024        Geral     Feminino          CDE            N      30 a 49
#
# 1      Leituras_6       Sexo  \
# ID
# ID    Bandeiras_6     P_SEXO
# ID     Leituras_6       Sexo
# ...

# %%
answers = answers.drop(answers.index[1])
answers
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 1         Geral  Masculino        CDE         SE    30 a 49    Android
# 2         Geral   Feminino        CDE         NE    16 a 29    Android
# 3         Geral   Feminino         AB          S    30 a 49    Android
# 4         Geral  Masculino        CDE         NE    30 a 49    Android
# 5         Geral   Feminino         AB         SE        50+    Android
# ...         ...        ...        ...        ...        ...        ...
# 2020      Geral   Feminino        CDE         SE    30 a 49    Não sei
# 2021      Geral   Feminino        CDE          S    30 a 49    Android
# 2022      Geral   Feminino        CDE          S    16 a 29    Android
# 2023      Geral   Feminino        CDE          N    16 a 29    Android
# 2024      Geral   Feminino        CDE          N    30 a 49    Android
#
# 1          Sexo  \
# ID
# 1     Masculino
# 2      Feminino
# 3      Feminino
# 4     Masculino
# ...

# %%
sns.countplot(y='Leituras_5', hue='Qual é a renda familiar mensal da sua residência? Por favor, considere a soma dos rendimentos de todos os moradores.', data=answers, palette="Greens_d")

# %%
ax = sns.countplot(x="Leituras_5", hue="Sexo", data=answers)

# %%
answers[(answers['Sexo'] == 'Feminino') & (answers['Leituras_5'] == '30 a 49')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 3         Geral   Feminino         AB          S    30 a 49    Android
# 14        Geral   Feminino        CDE         SE    30 a 49    Android
# 17        Geral   Feminino         AB         SE    30 a 49    Android
# 18        Geral   Feminino        CDE         SE    30 a 49    Android
# 25        Geral   Feminino         AB          S    30 a 49    Android
# ...         ...        ...        ...        ...        ...        ...
# 2018      Geral   Feminino        CDE         NE    30 a 49    Não sei
# 2019      Geral   Feminino        CDE         NE    30 a 49    Não sei
# 2020      Geral   Feminino        CDE         SE    30 a 49    Não sei
# 2021      Geral   Feminino        CDE          S    30 a 49    Android
# 2024      Geral   Feminino        CDE          N    30 a 49    Android
#
# 1         Sexo  \
# ID
# 3     Feminino
# 14    Feminino
# 17    Feminino
# 18    Feminino
# 25    Feminino
# ...

# %%
age_os = sns.countplot(x="Leituras_5", hue="Leituras_6", data=answers)

# %%
answers['Leituras_5'].describe()
# Out:
# count        2024
# unique          3
# top       30 a 49
# freq          950
# Name: Leituras_5, dtype: object

# %%
answers['Leituras_5']
# Out:
# ID
# 1       30 a 49
# 2       16 a 29
# 3       30 a 49
# 4       30 a 49
# 5           50+
#          ...
# 2020    30 a 49
# 2021    30 a 49
# 2022    16 a 29
# 2023    16 a 29
# 2024    30 a 49
# Name: Leituras_5, Length: 2024, dtype: object

# %%
answers[(answers['Leituras_5'] == '30 a 49')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 1         Geral  Masculino        CDE         SE    30 a 49    Android
# 3         Geral   Feminino         AB          S    30 a 49    Android
# 4         Geral  Masculino        CDE         NE    30 a 49    Android
# 6         Geral  Masculino        CDE         NE    30 a 49    Android
# 11        Geral  Masculino         AB         SE    30 a 49    Android
# ...         ...        ...        ...        ...        ...        ...
# 2018      Geral   Feminino        CDE         NE    30 a 49    Não sei
# 2019      Geral   Feminino        CDE         NE    30 a 49    Não sei
# 2020      Geral   Feminino        CDE         SE    30 a 49    Não sei
# 2021      Geral   Feminino        CDE          S    30 a 49    Android
# 2024      Geral   Feminino        CDE          N    30 a 49    Android
#
# 1          Sexo  \
# ID
# 1     Masculino
# 3      Feminino
# 4     Masculino
# 6     Masculino
# ...

# %%
answers[(answers['Leituras_5'] == '30 a 49') & (answers['Leituras_6'] == 'Android')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 1         Geral  Masculino        CDE         SE    30 a 49    Android
# 3         Geral   Feminino         AB          S    30 a 49    Android
# 4         Geral  Masculino        CDE         NE    30 a 49    Android
# 6         Geral  Masculino        CDE         NE    30 a 49    Android
# 11        Geral  Masculino         AB         SE    30 a 49    Android
# ...         ...        ...        ...        ...        ...        ...
# 2010      Geral   Feminino        CDE          S    30 a 49    Android
# 2015      Geral   Feminino        CDE         CO    30 a 49    Android
# 2017      Geral   Feminino        CDE         SE    30 a 49    Android
# 2021      Geral   Feminino        CDE          S    30 a 49    Android
# 2024      Geral   Feminino        CDE          N    30 a 49    Android
#
# 1          Sexo  \
# ID
# 1     Masculino
# 3      Feminino
# 4     Masculino
# 6     Masculino
# ...

# %%
answers[(answers['Leituras_5'] == '30 a 49') & (answers['Leituras_6'] == 'iOS')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 46        Geral  Masculino         AB         CO    30 a 49        iOS
# 47        Geral   Feminino         AB          S    30 a 49        iOS
# 48        Geral  Masculino        CDE         SE    30 a 49        iOS
# 63        Geral  Masculino         AB         SE    30 a 49        iOS
# 104       Geral  Masculino         AB          N    30 a 49        iOS
# ...         ...        ...        ...        ...        ...        ...
# 1803      Geral  Masculino        CDE         NE    30 a 49        iOS
# 1827      Geral   Feminino        CDE         SE    30 a 49        iOS
# 1843      Geral  Masculino        CDE         SE    30 a 49        iOS
# 1899      Geral   Feminino        CDE         NE    30 a 49        iOS
# 1995      Geral   Feminino        CDE         NE    30 a 49        iOS
#
# 1          Sexo  \
# ID
# 46    Masculino
# 47     Feminino
# 48    Masculino
# 63    Masculino
# ...

# %%
answers[(answers['Leituras_5'] == '16 a 29')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 2         Geral   Feminino        CDE         NE    16 a 29    Android
# 7         Geral   Feminino        CDE         SE    16 a 29    Android
# 8         Geral   Feminino        CDE         NE    16 a 29    Android
# 9         Geral   Feminino        CDE         SE    16 a 29    Android
# 16        Geral   Feminino         AB         SE    16 a 29        iOS
# ...         ...        ...        ...        ...        ...        ...
# 2013      Geral   Feminino        CDE         SE    16 a 29    Android
# 2014      Geral   Feminino        CDE         NE    16 a 29    Android
# 2016      Geral   Feminino        CDE         SE    16 a 29    Android
# 2022      Geral   Feminino        CDE          S    16 a 29    Android
# 2023      Geral   Feminino        CDE          N    16 a 29    Android
#
# 1         Sexo  \
# ID
# 2     Feminino
# 7     Feminino
# 8     Feminino
# 9     Feminino
# 16    Feminino
# ...

# %%
answers[(answers['Leituras_5'] == '16 a 29') & (answers['Leituras_6'] == 'iOS')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 16        Geral   Feminino         AB         SE    16 a 29        iOS
# 19        Geral  Masculino        CDE         SE    16 a 29        iOS
# 40        Geral   Feminino        CDE          S    16 a 29        iOS
# 66        Geral  Masculino         AB          S    16 a 29        iOS
# 83        Geral   Feminino        CDE         NE    16 a 29        iOS
# 137       Geral  Masculino        CDE         NE    16 a 29        iOS
# 146       Geral   Feminino        CDE         CO    16 a 29        iOS
# 200       Geral   Feminino        CDE         SE    16 a 29        iOS
# 215       Geral  Masculino         AB          S    16 a 29        iOS
# 220       Geral   Feminino        CDE         SE    16 a 29        iOS
# 245       Geral   Feminino        CDE          S    16 a 29        iOS
# 333       Geral   Feminino        CDE         NE    16 a 29        iOS
# ...

# %%
answers[(answers['Leituras_6'] == 'Outro')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 434       Geral   Feminino        CDE         SE    30 a 49      Outro
# 616       Geral  Masculino        CDE         SE    16 a 29      Outro
# 1684      Geral   Feminino        CDE         SE        50+      Outro
# 1793      Geral   Feminino        CDE          N    30 a 49      Outro
# 1930      Geral  Masculino        CDE         CO    16 a 29      Outro
# 1981      Geral  Masculino        CDE         SE        50+      Outro
# 1986      Geral  Masculino        CDE         SE        50+      Outro
#
# 1          Sexo  \
# ID
# 434    Feminino
# 616   Masculino
# 1684   Feminino
# 1793   Feminino
# 1930  Masculino
# 1981  Masculino
# 1986  Masculino
#
# 1    Qual é a renda familiar mensal da sua residência? Por favor, considere a soma dos rendimentos de todos os moradores.  \
# ID
# 434                                De R$2.995 a R$4.990
# 616                                  De R$999 a R$1.996
# ...

# %%
answers[(answers['Leituras_6'] == 'Não sei')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 516       Geral  Masculino        CDE         SE        50+    Não sei
# 1216      Geral   Feminino        CDE         SE        50+    Não sei
# 1314      Geral   Feminino        CDE         SE    30 a 49    Não sei
# 1439      Geral   Feminino        CDE         NE    30 a 49    Não sei
# 1599      Geral  Masculino         AB         SE        50+    Não sei
# 1671      Geral  Masculino        CDE         NE        50+    Não sei
# 1739      Geral   Feminino        CDE          N    30 a 49    Não sei
# 1896      Geral  Masculino        CDE         SE    30 a 49    Não sei
# 1922      Geral   Feminino        CDE         SE        50+    Não sei
# 1974      Geral  Masculino        CDE         SE        50+    Não sei
# 1989      Geral   Feminino         AB          S        50+    Não sei
# 2018      Geral   Feminino        CDE         NE    30 a 49    Não sei
# ...

# %%
age_os = sns.countplot(x="Leituras_6", hue="Qual é a renda familiar mensal da sua residência? Por favor, considere a soma dos rendimentos de todos os moradores.", data=answers)

# %%
answers[(answers['Você já realizou encomendas de produtos ou serviços através do WhatsApp?'] == 'Sim')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 1         Geral  Masculino        CDE         SE    30 a 49    Android
# 2         Geral   Feminino        CDE         NE    16 a 29    Android
# 3         Geral   Feminino         AB          S    30 a 49    Android
# 4         Geral  Masculino        CDE         NE    30 a 49    Android
# 5         Geral   Feminino         AB         SE        50+    Android
# ...         ...        ...        ...        ...        ...        ...
# 1871      Geral  Masculino        CDE         NE    30 a 49    Android
# 1873      Geral   Feminino        CDE          S    16 a 29    Android
# 1874      Geral  Masculino        CDE         SE    30 a 49    Android
# 1875      Geral  Masculino         AB         NE    16 a 29    Android
# 1995      Geral   Feminino        CDE         NE    30 a 49        iOS
#
# 1          Sexo  \
# ID
# 1     Masculino
# 2      Feminino
# 3      Feminino
# 4     Masculino
# ...

# %%
answers[answers['Você já realizou encomendas de produtos ou serviços através do WhatsApp?'].notnull() & (answers['Sexo'] == 'Feminino')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 2         Geral   Feminino        CDE         NE    16 a 29    Android
# 3         Geral   Feminino         AB          S    30 a 49    Android
# 5         Geral   Feminino         AB         SE        50+    Android
# 7         Geral   Feminino        CDE         SE    16 a 29    Android
# 8         Geral   Feminino        CDE         NE    16 a 29    Android
# ...         ...        ...        ...        ...        ...        ...
# 1882      Geral   Feminino        CDE          S    16 a 29    Android
# 1884      Geral   Feminino        CDE          S    30 a 49    Android
# 1995      Geral   Feminino        CDE         NE    30 a 49        iOS
# 2000      Geral   Feminino        CDE         CO    16 a 29    Android
# 2003      Geral   Feminino        CDE         SE    16 a 29    Android
#
# 1         Sexo  \
# ID
# 2     Feminino
# 3     Feminino
# 5     Feminino
# 7     Feminino
# 8     Feminino
# ...

# %%
# 1719 respostas: 867 mulheres (50.4%) e 852 homens (49.6%)
# 960 já usaram o WhatsApp para alguma compra (47.4% do sample total de 2024 e 55.8% do sample reduzido de 1719)
# 541 mulheres e 419 homens
# no total: 51.2% das mulheres e 43.3% dos homens
# sample reduzido: 62.4% das mulheres e 49.2% dos homens (número mais interessante??)

# %%
answers[(answers['Você diria que você realiza compras de produtos e serviços com mais frequência pelo smartphone ou pelo computador?'] == 'Smartphone') & (answers['Sexo'] == 'Feminino')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 2         Geral   Feminino        CDE         NE    16 a 29    Android
# 3         Geral   Feminino         AB          S    30 a 49    Android
# 5         Geral   Feminino         AB         SE        50+    Android
# 7         Geral   Feminino        CDE         SE    16 a 29    Android
# 8         Geral   Feminino        CDE         NE    16 a 29    Android
# ...         ...        ...        ...        ...        ...        ...
# 1873      Geral   Feminino        CDE          S    16 a 29    Android
# 1882      Geral   Feminino        CDE          S    16 a 29    Android
# 1884      Geral   Feminino        CDE          S    30 a 49    Android
# 2000      Geral   Feminino        CDE         CO    16 a 29    Android
# 2003      Geral   Feminino        CDE         SE    16 a 29    Android
#
# 1         Sexo  \
# ID
# 2     Feminino
# 3     Feminino
# 5     Feminino
# 7     Feminino
# 8     Feminino
# ...

# %%
# 1719 respostas: 867 mulheres (50.4%) e 852 homens (49.6%)
# 1255 smartphone (666 mulheres, 589 homens)
# 464 computador (201 mulheres, 263 homens)

# 76.8% das mulheres usam smartphone, 23.2% usam computador
# 69.1% dos homens usam smartphone, 30.9% usam computador

# %%
answers[(answers['Você já realizou encomendas de produtos ou serviços através do Facebook Messenger?'] == 'Sim') & (answers['Sexo'] == 'Feminino')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 2         Geral   Feminino        CDE         NE    16 a 29    Android
# 3         Geral   Feminino         AB          S    30 a 49    Android
# 5         Geral   Feminino         AB         SE        50+    Android
# 7         Geral   Feminino        CDE         SE    16 a 29    Android
# 8         Geral   Feminino        CDE         NE    16 a 29    Android
# ...         ...        ...        ...        ...        ...        ...
# 1847      Geral   Feminino        CDE         NE    30 a 49    Android
# 1850      Geral   Feminino        CDE         NE    16 a 29    Android
# 1855      Geral   Feminino         AB         SE    30 a 49    Android
# 1995      Geral   Feminino        CDE         NE    30 a 49        iOS
# 2000      Geral   Feminino        CDE         CO    16 a 29    Android
#
# 1         Sexo  \
# ID
# 2     Feminino
# 3     Feminino
# 5     Feminino
# 7     Feminino
# 8     Feminino
# ...

# %%
# 1719 respostas: 867 mulheres (50.4%) e 852 homens (49.6%)
# 682 já usaram o facebook messenger para compras (39.7%)
# 376 mulheres (43.4%) e 306 homens (35.9%)

# %%
answers[(answers['Você já realizou encomendas de produtos ou serviços através do Facebook Messenger?'] == 'Sim') & (answers['Você já realizou encomendas de produtos ou serviços através do WhatsApp?'] == 'Sim')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 1         Geral  Masculino        CDE         SE    30 a 49    Android
# 2         Geral   Feminino        CDE         NE    16 a 29    Android
# 3         Geral   Feminino         AB          S    30 a 49    Android
# 4         Geral  Masculino        CDE         NE    30 a 49    Android
# 5         Geral   Feminino         AB         SE        50+    Android
# ...         ...        ...        ...        ...        ...        ...
# 1855      Geral   Feminino         AB         SE    30 a 49    Android
# 1871      Geral  Masculino        CDE         NE    30 a 49    Android
# 1874      Geral  Masculino        CDE         SE    30 a 49    Android
# 1875      Geral  Masculino         AB         NE    16 a 29    Android
# 1995      Geral   Feminino        CDE         NE    30 a 49        iOS
#
# 1          Sexo  \
# ID
# 1     Masculino
# 2      Feminino
# 3      Feminino
# 4     Masculino
# ...

# %%
# 555 pessoas já usaram tanto whatsapp quanto facebook messenger (32.3% das pessoas)
# 318 mulheres (36.7%) e 237 homens (27.8%)

# %%
answers[(answers['Você já realizou encomendas de produtos ou serviços através do Facebook Messenger?'] == 'Sim') & (answers['Você já realizou encomendas de produtos ou serviços através do WhatsApp?'] == 'Não')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 17        Geral   Feminino         AB         SE    30 a 49    Android
# 19        Geral  Masculino        CDE         SE    16 a 29        iOS
# 25        Geral   Feminino         AB          S    30 a 49    Android
# 80        Geral  Masculino        CDE         NE    16 a 29    Android
# 90        Geral   Feminino         AB          S    16 a 29    Android
# ...         ...        ...        ...        ...        ...        ...
# 1841      Geral  Masculino        CDE          S    30 a 49    Android
# 1862      Geral  Masculino        CDE         NE    30 a 49    Android
# 1877      Geral  Masculino        CDE         SE        50+    Android
# 1878      Geral  Masculino        CDE         SE        50+    Android
# 2000      Geral   Feminino        CDE         CO    16 a 29    Android
#
# 1          Sexo  \
# ID
# 17     Feminino
# 19    Masculino
# 25     Feminino
# 80    Masculino
# ...

# %%
# apenas 127 pessoas (7.4%) das pessoas já utilizaram o facebook messenger e NÃO utilizaram o whatsApp

# %%
answers[(answers['Você já realizou encomendas de produtos ou serviços através do Facebook Messenger?'] == 'Não') & (answers['Você já realizou encomendas de produtos ou serviços através do WhatsApp?'] == 'Sim')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 12        Geral  Masculino         AB         SE    30 a 49    Android
# 15        Geral   Feminino        CDE         CO        50+    Android
# 16        Geral   Feminino         AB         SE    16 a 29        iOS
# 43        Geral  Masculino         AB          N    30 a 49    Android
# 49        Geral   Feminino         AB         NE    16 a 29    Android
# ...         ...        ...        ...        ...        ...        ...
# 1840      Geral   Feminino        CDE         SE    30 a 49    Android
# 1844      Geral   Feminino        CDE         CO    16 a 29    Android
# 1851      Geral   Feminino        CDE          N    30 a 49    Android
# 1857      Geral   Feminino        CDE         SE    30 a 49    Android
# 1873      Geral   Feminino        CDE          S    16 a 29    Android
#
# 1          Sexo  \
# ID
# 12    Masculino
# 15     Feminino
# 16     Feminino
# 43    Masculino
# ...

# %%
# 405 pessoas (23.5%) já utilizaram o whatsApp e NÃO utilizaram o facebook messenger

# %%
answers['Você já solicitou uma corrida de automóvel através de um aplicativo no smartphone?'].value_counts()
# Out:
# Sim    1510
# Não     514
# Name: Você já solicitou uma corrida de automóvel através de um aplicativo no smartphone?, dtype: int64

# %%
# 2024 total: 1056 mulheres e 968 homens
# 74.6% já solicitaram corrida de automóvel por app

# %%
answers[(answers['Você já solicitou uma corrida de automóvel através de um aplicativo no smartphone?'] == 'Sim') & (answers['Sexo'] == 'Feminino')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 2         Geral   Feminino        CDE         NE    16 a 29    Android
# 3         Geral   Feminino         AB          S    30 a 49    Android
# 5         Geral   Feminino         AB         SE        50+    Android
# 7         Geral   Feminino        CDE         SE    16 a 29    Android
# 8         Geral   Feminino        CDE         NE    16 a 29    Android
# ...         ...        ...        ...        ...        ...        ...
# 1701      Geral   Feminino        CDE          N    30 a 49    Android
# 1702      Geral   Feminino        CDE         SE        50+    Android
# 1704      Geral   Feminino        CDE         NE    30 a 49    Android
# 1705      Geral   Feminino        CDE         SE        50+    Android
# 1708      Geral   Feminino        CDE         NE    16 a 29    Android
#
# 1         Sexo  \
# ID
# 2     Feminino
# 3     Feminino
# 5     Feminino
# 7     Feminino
# 8     Feminino
# ...

# %%
# 785 mulheres (74.3%) e 725 homens (74.9%)

# %%
answers[(answers['Você já pediu uma refeição através de um aplicativo no smartphone?'] == 'Sim') & (answers['Sexo'] == 'Feminino')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 2         Geral   Feminino        CDE         NE    16 a 29    Android
# 3         Geral   Feminino         AB          S    30 a 49    Android
# 5         Geral   Feminino         AB         SE        50+    Android
# 7         Geral   Feminino        CDE         SE    16 a 29    Android
# 8         Geral   Feminino        CDE         NE    16 a 29    Android
# ...         ...        ...        ...        ...        ...        ...
# 1430      Geral   Feminino        CDE         CO    30 a 49    Android
# 1431      Geral   Feminino        CDE         SE    16 a 29    Android
# 1433      Geral   Feminino        CDE         SE    16 a 29    Android
# 1434      Geral   Feminino        CDE         SE        50+    Android
# 1435      Geral   Feminino        CDE         NE    30 a 49    Android
#
# 1         Sexo  \
# ID
# 2     Feminino
# 3     Feminino
# 5     Feminino
# 7     Feminino
# 8     Feminino
# ...

# %%
# 62.4% já pediram refeição por app
# 646 mulheres (61.2%) e 616 homens (63.6%)

# %%
answers['Você já solicitou um serviço de beleza (manicure, cabeleireiro, maquiador etc) a domicílio através de um aplicativo no smartphone?'].value_counts()
# Out:
# Não    1757
# Sim     267
# Name: Você já solicitou um serviço de beleza (manicure, cabeleireiro, maquiador etc) a domicílio através de um aplicativo no smartphone?, dtype: int64

# %%
answers[(answers['Você já solicitou um serviço de beleza (manicure, cabeleireiro, maquiador etc) a domicílio através de um aplicativo no smartphone?'] == 'Sim') & (answers['Sexo'] == 'Feminino')]
# Out:
# 1   Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 2        Geral   Feminino        CDE         NE    16 a 29    Android
# 3        Geral   Feminino         AB          S    30 a 49    Android
# 5        Geral   Feminino         AB         SE        50+    Android
# 7        Geral   Feminino        CDE         SE    16 a 29    Android
# 9        Geral   Feminino        CDE         SE    16 a 29    Android
# ..         ...        ...        ...        ...        ...        ...
# 404      Geral   Feminino        CDE         SE    30 a 49    Android
# 405      Geral   Feminino        CDE         CO    30 a 49    Android
# 406      Geral   Feminino        CDE         SE    30 a 49    Android
# 407      Geral   Feminino        CDE         SE    30 a 49    Android
# 408      Geral   Feminino        CDE         SE    30 a 49    Android
#
# 1        Sexo  \
# ID
# 2    Feminino
# 3    Feminino
# 5    Feminino
# 7    Feminino
# 9    Feminino
# ..        ...
# ...

# %%
# 267 já solicitaram serviço de beleza (13.2%)
# 179 mulheres (17%) e 88 homens (9.1%)

# %%
# 867 mulheres (82.1%) e 852 homens (88%) já encomendaram alguma mercadoria pelo smartphone

# %%
# past data points -> trend comparisons (instagram tem sido mais utilizado no geral, mas as compras pelo app tem aumentado proporcionalmente?)
#

# %%
answers[(answers['Você tem conta em algum banco digital ou carteira digital, cuja conta foi criada através de um aplicativo no smartphone?'] == 'Sim') & (answers['Sexo'] == 'Feminino')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 2         Geral   Feminino        CDE         NE    16 a 29    Android
# 3         Geral   Feminino         AB          S    30 a 49    Android
# 5         Geral   Feminino         AB         SE        50+    Android
# 7         Geral   Feminino        CDE         SE    16 a 29    Android
# 8         Geral   Feminino        CDE         NE    16 a 29    Android
# ...         ...        ...        ...        ...        ...        ...
# 1988      Geral   Feminino        CDE         NE    16 a 29    Android
# 2012      Geral   Feminino        CDE         SE    16 a 29    Android
# 2019      Geral   Feminino        CDE         NE    30 a 49    Não sei
# 2020      Geral   Feminino        CDE         SE    30 a 49    Não sei
# 2024      Geral   Feminino        CDE          N    30 a 49    Android
#
# 1         Sexo  \
# ID
# 2     Feminino
# 3     Feminino
# 5     Feminino
# 7     Feminino
# 8     Feminino
# ...

# %%
temprev = answers[(answers['Você tem conta em algum banco digital ou carteira digital, cuja conta foi criada através de um aplicativo no smartphone?'] == 'Sim')]
temprev['Qual é a renda familiar mensal da sua residência? Por favor, considere a soma dos rendimentos de todos os moradores.'].value_counts()
# Out:
# De R$999 a R$1.996       261
# De R$1.997 a R$2.994     244
# De R$2.995 a R$4.990     235
# De R$4.991 a R$9.980     169
# Até R$998                 89
# De R$9.981 a R$14.970     61
# Mais de R$14.970          19
# Name: Qual é a renda familiar mensal da sua residência? Por favor, considere a soma dos rendimentos de todos os moradores., dtype: int64

# %%
answers['Qual é a renda familiar mensal da sua residência? Por favor, considere a soma dos rendimentos de todos os moradores.'].value_counts()
# Out:
# De R$999 a R$1.996       507
# De R$1.997 a R$2.994     441
# De R$2.995 a R$4.990     418
# De R$4.991 a R$9.980     289
# Até R$998                218
# De R$9.981 a R$14.970    108
# Mais de R$14.970          43
# Name: Qual é a renda familiar mensal da sua residência? Por favor, considere a soma dos rendimentos de todos os moradores., dtype: int64

# %%
# relação entre renda familiar e criação de conta em bancos digitais (hipótese: rendas maiores vão ter % maior)
# Até R$998: 40.8%
# De R$999 a R$1.996: 51.5%
# De R$1.997 a R$2.994: 55.3%
# De R$2.995 a R$4.990: 56.2%
# De R$4.991 a R$9.980: 58.5%
# De R$9.981 a R$14.970: 56.5% (amostragem pequena?)
# Mais de R$14.970: 44.2% (amostragem bem pequena)

# %%
# 1078 pessoas já criaram conta em algum banco ou carteira digital (53.2%)
# 505 mulheres (47.8%) e 573 homens (59.1%)

# %%
answers[(answers['Você tem conta em algum banco tradicional, cuja conta você precisou comparecer a uma agência para abrir?'] == 'Sim')]
# Out:
# 1    Leituras_1 Leituras_2 Leituras_3 Leituras_4 Leituras_5 Leituras_6  \
# ID
# 1         Geral  Masculino        CDE         SE    30 a 49    Android
# 2         Geral   Feminino        CDE         NE    16 a 29    Android
# 3         Geral   Feminino         AB          S    30 a 49    Android
# 4         Geral  Masculino        CDE         NE    30 a 49    Android
# 5         Geral   Feminino         AB         SE        50+    Android
# ...         ...        ...        ...        ...        ...        ...
# 2015      Geral   Feminino        CDE         CO    30 a 49    Android
# 2018      Geral   Feminino        CDE         NE    30 a 49    Não sei
# 2020      Geral   Feminino        CDE         SE    30 a 49    Não sei
# 2021      Geral   Feminino        CDE          S    30 a 49    Android
# 2023      Geral   Feminino        CDE          N    16 a 29    Android
#
# 1          Sexo  \
# ID
# 1     Masculino
# 2      Feminino
# 3      Feminino
# 4     Masculino
# ...

# %%
# 1575 pessoas já criaram conta em bancos em agências
# 797 mulheres (75.5%) e 778 homens (80.3%)

# %%
triple_column = answers['Cite até três nomes de apps ou sites que você mais usa para fazer encomendas pelo smartphone.']
triple_column.columns = ['a', 'b', 'c']
triple_column[(triple_column['a'] == 'instagram') | (triple_column['a'] == 'Instagram') | (triple_column['b'] == 'instagram') | (triple_column['b'] == 'Instagram') | (triple_column['c'] == 'instagram') | (triple_column['c'] == 'Instagram') ]
# Out:
#                   a              b          c
# ID
# 37              OLX       Facebook  Instagram
# 130        facebook      instagram        NaN
# 138      Americanas       Magazine  Instagram
# 243       Instagram  Mercado livre   Whatsapp
# 245       Instagram      Uber Hits        NaN
# 324        Whatsapp      Messenger  Instagram
# 339   Mercado livre       Facebook  Instagram
# 581        Whatsapp      Instagram     Dafiti
# 603       Instagram  Mercado Livre      iFood
# 837   Mercado livre           Wisk  Instagram
# 912       messenger       Whatsapp  Instagram
# 1232          ifood      instagram        NaN
# 1363       Whatsapp       Facebook  Instagram
# 1494      instagram           wtts   facebook

# %%
# 3 pesquisas: uso de apps no brasil, comércio eletrônico, apps de mensageria

# 72% dos internautas possuem Instagram instalado no celular (PESQUISA 1: mensageria)
# 14 usuários (0.8%) citaram instagram como usado para fazer encomendas


# 98% dos internautas possuem whatsApp (PESQUISA 1: mensageria)
# 6% citaram o whatsApp como usado para fazer encomendas

# 79% dos internautas possuem Messenger (PESQUISA 1: mensageria)
# 12 usuários (0.7%) citaram messenger como usado para fazer encomendas
# somente 1 usuário que citou messenger, não citou whatsApp (% irrelevante pelo sample size?)

# 3.4% citaram facebook OU messenger

####### avaliar esses números para os outros anos (utilização do app X citação em encomendas)

# 47.4% já usaram o whatsApp para alguma compra
# 33.7% já usaram o facebook messenger para alguma compra


# home screen dos internautas:
# whatsApp (59%), facebook (47%) e instagram (37%), messenger (15%)
# citado em apps utilizados para encomendas:
# whatsApp (6%), facebook/messenger (3.4%), instagram (0.7%)

# home screen dos internautas:
# iFood (6%), mercado livre (4%) e olx (4%), americanas (2-3%) e magazine luiza (2-3%)
# citado em apps utilizados para encomendas:
# iFood (27%), mercado livre (40%) e olx (7%), americanas (38%)  e magazine luiza (18%)

# presunções?

# apesar de estarem instalados na maioria dos celulares e já terem sido usados para alguma compra, 
# o whatsApp/Instagram/Messenger tem pouca representatividade no comério eletrônico.
# ou seja, o 'problema' não é a falta de acesso ao app dos usuários.

# boa parte dos internautas já passaram pela experiência de comprar pelo whatsApp/Messenger, mas a maior parte do
# consumo é feito por apps especialistas (mercado livre, americanas, magazine luiza, etc).
# os users já sabem da existência do e-commerce no wpp/fb, pq não é mais utilizado? produtos oferecidos, processo
# de compra

# internautas que usam o messenger para compras são majoritariamente um subgrupo de internautas que usam o wpp.
# messenger não tem usuários 'exclusivos'

# wpp, instagram e facebook são os apps mais priorizados pelos internautas, entretanto o comércio é feito através
# de apps especialistas - importância dos apps de empresas como americanas e submarino, entregam uma melhor
# experiência pro usuário (referenciar funcionalidades mais importantes)

# o app atrai clientes ou os clientes fidelizados baixam o app? quantos apps 'especialistas' o usuário tem instalado?

# "swipe up" no instagram não é tão efetivo? ou a compra realizada é contabilizada como sendo fora do app?

# telegram aparece com parcela significativa como app de mensageria, mas é citado apenas 1x como app de compra - 
# e é citado por usuário que também citou whatsapp e messenger (text/chat-buyer)

# seria interessante saber o range de preço das compras de cada app

# text-based buyer: negócios menores, conversa com quem oferta o serviço, pedido por chat, processo manual
# app-based buyer: empresas maiores, processo automatizado, cliente escolhe e paga sem nenhum contato (opcional)

# whatsApp lançou a versão business ('built with the small business owner in mind') - tentativa de captar o mercado
# de text-based buyers e expandir a fatia pros app-based? monetização
# prediction: whatsApp cresce ainda mais entre pequenos negócios e continua presente em grande maioria dos 'text-
# based buyers' (messenger e telegram não conseguem captar parcela exclusiva de clientes)

# exemplo black friday: 53.8% do público (maior parcela) está interessada em eletrodomésticos (encontrados em apps
# especialistas, usualmente). 

# e-commerce no brasil: em crescimento (12% no 1o semestre de 2019), receita na casa dos 26 bilhões.
# 65.2 milhões de compras efetuadas (~R$400 de média)
# 18% dos consumidores tiveram sua 1a experiência nesse ano
# números de acordo com a pesquisa do uso de apps, que indica o crescimento de apps como uber, ifood, etc

# transformação do smartphone em uma ferramenta de APENAS comunicação (ligações, mensagens instantâneas) para
# uma ferramenta 'multitask' - crescimento da presença de bancos digitais, apps de comércio, etc em termos proporcionais.
# apps de comunicação em leve crescente, enquanto apps de e-commerce crescem muito

# %%
triple_column_messenger = answers['Cite até três nomes de apps ou sites que você mais usa para fazer encomendas pelo smartphone.']
triple_column_messenger.columns = ['a', 'b', 'c']
triple_column_messenger[(triple_column_messenger['a'] == 'messenger') | (triple_column_messenger['a'] == 'Messenger') | (triple_column_messenger['b'] == 'messenger') | (triple_column_messenger['b'] == 'Messenger') | (triple_column_messenger['c'] == 'messenger') | (triple_column_messenger['c'] == 'Messenger')]
# Out:
#               a          b              c
# ID
# 67        iFood  Whats app      Messenger
# 228    Whatsaap   Facebook      Messenger
# 246    Whatsapp  Messenger            NaN
# 262     watsapp  messenger       telegram
# 324    Whatsapp  Messenger      Instagram
# 364    Whatsapp  Messenger          Ifood
# 378    whatsapp  messenger  mercado livre
# 912   messenger   Whatsapp      Instagram
# 974    Whatsapp   Facebook      Messenger
# 1059  messenger      ifood            NaN
# 1176   WhatsApp      Ifood      Messenger
# 1421   WhatsApp  Messenger          Ifood

# %%
triple_column_telegram = answers['Cite até três nomes de apps ou sites que você mais usa para fazer encomendas pelo smartphone.']
triple_column_telegram.columns = ['a', 'b', 'c']
triple_column_telegram[(triple_column_telegram['a'] == 'telegram') | (triple_column_telegram['a'] == 'Telegram') | (triple_column_telegram['b'] == 'telegram') | (triple_column_telegram['b'] == 'Telegram') | (triple_column_telegram['c'] == 'telegram') | (triple_column_telegram['c'] == 'Telegram')]
# Out:
#            a          b         c
# ID
# 262  watsapp  messenger  telegram
